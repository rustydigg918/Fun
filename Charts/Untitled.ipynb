# %%
# !pip install opendatasets --upgrade --quiet

# %%
import pandas as pd
import seaborn as sns

# %%
bank_df = pd.read_csv(r"C:\Pushkar\User data 25-08-2020\datasets\banking.csv")
bank_df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       44  blue-collar  married             basic.4y  unknown     yes   no
# 1       53   technician  married              unknown       no      no   no
# 2       28   management   single    university.degree       no     yes   no
# 3       39     services  married          high.school       no      no   no
# 4       55      retired  married             basic.4y       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   59      retired  married          high.school  unknown      no  yes
# 41184   31    housemaid  married             basic.4y  unknown      no   no
# 41185   42       admin.   single    university.degree  unknown     yes  yes
# 41186   48   technician  married  professional.course       no      no  yes
# 41187   25      student   single          high.school       no      no   no
#
# ...

# %%
bank_df['cons_price_idx'][:50]
# Out:
# 0     93.444
# 1     93.200
# 2     94.055
# 3     93.075
# 4     92.201
# 5     93.918
# 6     92.893
# 7     92.893
# 8     92.963
# 9     93.075
# 10    93.994
# 11    93.444
# 12    93.444
# 13    92.893
# 14    94.465
# 15    93.918
# 16    93.075
# 17    93.798
# 18    93.994
# 19    93.918
# 20    93.075
# 21    94.465
# 22    93.918
# 23    93.918
# 24    93.918
# 25    92.893
# 26    92.431
# 27    93.075
# 28    92.893
# 29    93.918
# 30    94.465
# 31    92.893
# 32    92.893
# 33    92.963
# 34    93.918
# 35    92.893
# 36    93.918
# 37    93.075
# 38    94.465
# 39    93.444
# 40    93.994
# 41    93.994
# 42    93.918
# 43    92.649
# 44    93.444
# 45    93.200
# 46    93.444
# 47    92.893
# 48    93.444
# 49    94.465
# Name: cons_price_idx, dtype: float64

# %%
bank_df['campaign'][1:10]
# Out:
# 1    1
# 2    3
# 3    2
# 4    1
# 5    8
# 6    1
# 7    1
# 8    1
# 9    2
# Name: campaign, dtype: int64

# %% [markdown]
# ## Line Plot

# %%
bank_df['campaign'][1:10].plot(kind = 'line', grid=True);

# %% [markdown]
# ##  Bar

# %%
bank_df['campaign'][1:10].plot(kind = 'bar', grid=True);

# %%
bank_df['campaign'][1:10].plot(kind = 'pie', grid=True);

# %%
sns.distplot(bank_df['cons_price_idx']);
